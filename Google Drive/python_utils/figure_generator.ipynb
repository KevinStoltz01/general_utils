# %% [markdown]
# To do:
#
# 1. Get to work on an (n, n), n > 1 plot... It's going to be a mess

# %%
# %matplotlib inline

import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path

# %%
FIGURE_SIZE = (20, 10)
FIGURE_TITLE = "I like my figures"
FIGURE_TITLE_FONT_SIZE = 16
SHAREX = True
SHAREY = True

AX_LAYOUT = (2, 1)
AX_TITLES = [None, "YESSSSS"]
AX_TITLE_FONT_SIZE = 16

X_AXIS_LABEL = "X"
Y_AXIS_LABEL = "Y"
AXIS_LABEL_FONT_SIZE = 14

SHAREXLABEL = True
SHAREYLABEL = True

TICK_FONT_SIZE = 12
TICK_FONT_SIZE = 12

# %%
# %run "/Users/kevinstoltz/Google Drive/python_utils/plot_formatting.ipynb"

# %%
args = pack_args()
plot_format = FormattedPlot(**args)
fig, ax = plot_format.generate_formatted_figure()
